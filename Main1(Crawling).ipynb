# %%
import sys
import platform
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs
from urllib.parse import urlencode
import urllib3
import string
import json

# %% [markdown]
# #### https://csdl-api.computer.org/api/v1/graphql (GraphiQL 주소)

# %% [raw]
# #Periocials
# #idPrefix와 title, 그리고 yearFrom,yearTo를 얻을 수 있다.
# query {
#   periodicals(pubType:"journal") {
#     idPrefix
#     title
#     yearFrom
#     yearTo
#   }
# }
#
# #year(month)별 volume
# query {
#   periodicalIssues(idPrefix:"ci") {
#     label
#     issueNum
#     volume
#     year
#   }
# }
#
# #idPrefix, year, issueNum을 통해 article 크롤링
# query {
#   articles(idPrefix: "cc", year: "2018", issueNum: "02") {
#     idPrefix
#     id
#     year
#     pubDate
#     keywords
#     title
#     abstract
#     authors {
#       affiliation
#       fullName
#       givenName
#       surname
#     }
#     #catalog
#     #contentType
#     #pages
#     #pubType
#     #sectionTitle
#     #volume
#   }
# }

# %% [markdown]
# ##### Periodicals로 idPrefix, title, yearFrom, yearTo 얻기

# %%
resp = requests.post("https://csdl-api.computer.org/api/v1/graphql", 
                      json={
                          "query":'query { periodicals(pubType:"journal") { idPrefix title yearFrom yearTo } }'
                      })
body = resp.json()

# %%
print(json.dumps(body, indent=4))
# Out:
# {
#     "data": {
#         "periodicals": [
#             {
#                 "idPrefix": "cq",
#                 "title": "Colloquium",
#                 "yearFrom": 2017,
#                 "yearTo": 2019
#             },
#             {
#                 "idPrefix": "dc",
#                 "title": "IEEE Journal on Exploratory Solid-State Computational Devices and Circuits",
#                 "yearFrom": 2015,
#                 "yearTo": 2019
#             },
#             {
#                 "idPrefix": "ta",
#                 "title": "IEEE Transactions on Affective Computing",
#                 "yearFrom": 2010,
#                 "yearTo": 2019
#             },
#             {
#                 "idPrefix": "bd",
#                 "title": "IEEE Transactions on Big Data",
#                 "yearFrom": 2015,
#                 "yearTo": 2019
#             },
#             {
#                 "idPrefix": "cc",
#                 "title": "IEEE Transactions on Cloud Computing",
#                 "yearFrom": 2013,
#                 "yearTo": 2019
#             },
#             {
#                 "idPrefix": "ci",
#                 "title": "IEEE Transactions on Computational Intelligence and AI in Games",
#                 "yearFrom": 2009,
#                 "yearTo": 2017
#             },
#             {
#                 "idPrefix": "tc",
#                 "title": "IEEE Transactions on Computers",
#                 "yearFrom": 1968,
#                 "yearTo": 2019
#             },
#             {
#                 "idPrefix": "tq",
#                 "title": "IEEE Transactions on Dependable and Secure Computing",
#                 "yearFrom": 2004,
#                 "yearTo": 2019
#             },
#             {
#                 "idPrefix": "ec",
#                 "title": "IEEE Transactions on Emerging Topics in Computing",
#                 "yearFrom": 2013,
#                 "yearTo": 2019
#             },
#             {
#                 "idPrefix": "th",
#                 "title": "IEEE Transactions on Haptics",
#                 "yearFrom": 2008,
#                 "yearTo": 2017
#             },
#             {
#                 "idPrefix": "tk",
#                 "title": "IEEE Transactions on Knowledge & Data Engineering",
#                 "yearFrom": 1989,
#                 "yearTo": 2019
#             },
#             {
#                 "idPrefix": "lt",
#                 "title": "IEEE Transactions on Learning Technologies",
#                 "yearFrom": 2008,
#                 "yearTo": 2017
#             },
#             {
#                 "idPrefix": "tm",
#                 "title": "IEEE Transactions on Mobile Computing",
#                 "yearFrom": 2002,
#                 "yearTo": 2019
#             },
#             {
#                 "idPrefix": "mc",
#                 "title": "IEEE Transactions on Multi-Scale Computing Systems",
#                 "yearFrom": 2015,
#                 "yearTo": 2018
#             },
#             {
#                 "idPrefix": "tn",
#                 "title": "IEEE Transactions on Network Science and Engineering",
#                 "yearFrom": 2014,
#                 "yearTo": 2018
#             },
#             {
#                 "idPrefix": "td",
#                 "title": "IEEE Transactions on Parallel & Distributed Systems",
#                 "yearFrom": 1990,
#                 "yearTo": 2019
#             },
#             {
#                 "idPrefix": "tp",
#                 "title": "IEEE Transactions on Pattern Analysis & Machine Intelligence",
#                 "yearFrom": 1979,
#                 "yearTo": 2019
#             },
#             {
#                 "idPrefix": "sc",
#                 "title": "IEEE Transactions on Services Computing",
#                 "yearFrom": 2008,
#                 "yearTo": 2019
#             },
#             {
#                 "idPrefix": "ts",
#                 "title": "IEEE Transactions on Software Engineering",
#                 "yearFrom": 1975,
#                 "yearTo": 2019
#             },
#             {
#                 "idPrefix": "su",
#                 "title": "IEEE Transactions on Sustainable Computing",
#                 "yearFrom": 2016,
#                 "yearTo": 2019
#             },
#             {
#                 "idPrefix": "si",
#                 "title": "IEEE Transactions on Very Large Scale Integration (VLSI) Systems",
#                 "yearFrom": 1993,
#                 "yearTo": 2019
#             },
#             {
#                 "idPrefix": "tg",
#                 "title": "IEEE Transactions on Visualization & Computer Graphics",
#                 "yearFrom": 1995,
#                 "yearTo": 2019
#             },
#             {
#                 "idPrefix": "tb",
#                 "title": "IEEE/ACM Transactions on Computational Biology and Bioinformatics",
#                 "yearFrom": 2004,
#                 "yearTo": 2019
#             },
#             {
#                 "idPrefix": "nt",
#                 "title": "IEEE/ACM Transactions on Networking",
#                 "yearFrom": 1993,
#                 "yearTo": 2019
#             },
#             {
#                 "idPrefix": "ca",
#                 "title": "IEEE Computer Architecture Letters",
#                 "yearFrom": 2002,
#                 "yearTo": 2019
#             },
#             {
#                 "idPrefix": "lc",
#                 "title": "IEEE Letters of the Computer Society",
#                 "yearFrom": 2018,
#                 "yearTo": 2019
#             }
#         ]
#     }
# }

# %%
journals = [] # (title, idPrefix, yearFrom, yearTo)

for i in range(0,len(body["data"]["periodicals"])):
    journals.append( ( (body["data"]["periodicals"][i]['title']), body["data"]["periodicals"][i]['idPrefix'], body["data"]["periodicals"][i]['yearFrom'], body["data"]["periodicals"][i]['yearTo']) )

# %%
journals
# Out:
# [('Colloquium', 'cq', 2017, 2019),
#  ('IEEE Journal on Exploratory Solid-State Computational Devices and Circuits',
#   'dc',
#   2015,
#   2019),
#  ('IEEE Transactions on Affective Computing', 'ta', 2010, 2019),
#  ('IEEE Transactions on Big Data', 'bd', 2015, 2019),
#  ('IEEE Transactions on Cloud Computing', 'cc', 2013, 2019),
#  ('IEEE Transactions on Computational Intelligence and AI in Games',
#   'ci',
#   2009,
#   2017),
#  ('IEEE Transactions on Computers', 'tc', 1968, 2019),
#  ('IEEE Transactions on Dependable and Secure Computing', 'tq', 2004, 2019),
#  ('IEEE Transactions on Emerging Topics in Computing', 'ec', 2013, 2019),
#  ('IEEE Transactions on Haptics', 'th', 2008, 2017),
#  ('IEEE Transactions on Knowledge & Data Engineering', 'tk', 1989, 2019),
#  ('IEEE Transactions on Learning Technologies', 'lt', 2008, 2017),
#  ('IEEE Transactions on Mobile Computing', 'tm', 2002, 2019),
#  ('IEEE Transactions on Multi-Scale Computing Systems', 'mc', 2015, 2018),
#  ('IEEE Transactions on Network Science and Engineering', 'tn', 2014, 2018),
#  ('IEEE Transactions on Parallel & Distributed Systems', 'td', 1990, 2019),
#  ('IEEE Transactions on Pattern Analysis & Machine Intelligence',
#   'tp',
#   1979,
#   2019),
#  ('IEEE Transactions on Services Computing', 'sc', 2008, 2019),
#  ('IEEE Transactions on Software Engineering', 'ts', 1975, 2019),
#  ('IEEE Transactions on Sustainable Computing', 'su', 2016, 2019),
#  ('IEEE Transactions on Very Large Scale Integration (VLSI) Systems',
#   'si',
#   1993,
#   2019),
#  ('IEEE Transactions on Visualization & Computer Graphics', 'tg', 1995, 2019),
#  ('IEEE/ACM Transactions on Computational Biology and Bioinformatics',
#   'tb',
#   2004,
#   2019),
#  ('IEEE/ACM Transactions on Networking', 'nt', 1993, 2019),
#  ('IEEE Computer Architecture Letters', 'ca', 2002, 2019),
#  ('IEEE Letters of the Computer Society', 'lc', 2018, 2019)]

# %%
labels = ["journalName", "journalId", "yearFrom", "yearTo"]
journals_meta_df = pd.DataFrame.from_records(journals, columns=labels)

# %%
journals_meta_df
# Out:
#                                           journalName journalId  yearFrom  \
# 0                                          Colloquium        cq      2017
# 1   IEEE Journal on Exploratory Solid-State Comput...        dc      2015
# 2            IEEE Transactions on Affective Computing        ta      2010
# 3                       IEEE Transactions on Big Data        bd      2015
# 4                IEEE Transactions on Cloud Computing        cc      2013
# 5   IEEE Transactions on Computational Intelligenc...        ci      2009
# 6                      IEEE Transactions on Computers        tc      1968
# 7   IEEE Transactions on Dependable and Secure Com...        tq      2004
# 8   IEEE Transactions on Emerging Topics in Computing        ec      2013
# 9                        IEEE Transactions on Haptics        th      2008
# 10  IEEE Transactions on Knowledge & Data Engineering        tk      1989
# 11         IEEE Transactions on Learning Technologies        lt      2008
# 12              IEEE Transactions on Mobile Computing        tm      2002
# 13  IEEE Transactions on Multi-Scale Computing Sys...        mc      2015
# 14  IEEE Transactions on Network Science and Engin...        tn      2014
# 15  IEEE Transactions on Parallel & Distributed Sy...        td      1990
# 16  IEEE Transactions on Pattern Analysis & Machin...        tp      1979
# 17            IEEE Transactions on Services Computing        sc      2008
# 18          IEEE Transactions on Software Engineering        ts      1975
# 19         IEEE Transactions on Sustainable Computing        su      2016
# 20  IEEE Transactions on Very Large Scale Integrat...        si      1993
# 21  IEEE Transactions on Visualization & Computer ...        tg      1995
# 22  IEEE/ACM Transactions on Computational Biology...        tb      2004
# 23                IEEE/ACM Transactions on Networking        nt      1993
# 24                 IEEE Computer Architecture Letters        ca      2002
# 25               IEEE Letters of the Computer Society        lc      2018
#
#     yearTo
# 0     2019
# 1     2019
# 2     2019
# 3     2019
# 4     2019
# 5     2017
# 6     2019
# 7     2019
# 8     2019
# 9     2017
# 10    2019
# 11    2017
# 12    2019
# 13    2018
# 14    2018
# 15    2019
# 16    2019
# 17    2019
# 18    2019
# 19    2019
# 20    2019
# 21    2019
# 22    2019
# 23    2019
# 24    2019
# 25    2019

# %% [markdown]
# ##### PeriodicalIssues로 year, volume, issueNum 얻기

# %%
journals_df = pd.DataFrame()

for i in range(0, len(journals)) :
    resp = requests.post("https://csdl-api.computer.org/api/v1/graphql", 
                          json={
                              "variables":{"idPrefix":"%s"%(journals[i][1])},
                              "query":'query ($idPrefix : String!) { periodicalIssues(idPrefix : $idPrefix) { label issueNum volume year } }'
                          })
    body = resp.json()
    
    labels = ["journalId", "year", "issueNum", "volume"]
    temp_df = pd.DataFrame(body['data']['periodicalIssues'], columns=labels)
    temp_df['journalId'] = journals[i][1]
    journals_df = journals_df.append(temp_df)
    
    
    #Todo : 저널 별로 year, volume, issueNum 저장
    print("Progress : %d of %d (%s)" % (i+1, len(journals), journals[i][1]))
# Out:
# Progress : 1 of 26 (cq)
# Progress : 2 of 26 (dc)
# Progress : 3 of 26 (ta)
# Progress : 4 of 26 (bd)
# Progress : 5 of 26 (cc)
# Progress : 6 of 26 (ci)
# Progress : 7 of 26 (tc)
# Progress : 8 of 26 (tq)
# Progress : 9 of 26 (ec)
# Progress : 10 of 26 (th)
# Progress : 11 of 26 (tk)
# Progress : 12 of 26 (lt)
# Progress : 13 of 26 (tm)
# Progress : 14 of 26 (mc)
# Progress : 15 of 26 (tn)
# Progress : 16 of 26 (td)
# Progress : 17 of 26 (tp)
# Progress : 18 of 26 (sc)
# Progress : 19 of 26 (ts)
# Progress : 20 of 26 (su)
# Progress : 21 of 26 (si)
# Progress : 22 of 26 (tg)
# Progress : 23 of 26 (tb)
# Progress : 24 of 26 (nt)
# Progress : 25 of 26 (ca)
# Progress : 26 of 26 (lc)

# %%
journals_df
# Out:
#    journalId  year issueNum volume
# 0         cq  2017       01      1
# 1         cq  2017       02      1
# 2         cq  2017       03      1
# 3         cq  2017       04      1
# 4         cq  2017       05      1
# 5         cq  2017       06      1
# 6         cq  2017       07      1
# 7         cq  2017       08      1
# 8         cq  2017       09      1
# 9         cq  2017       10      1
# 10        cq  2017       11      1
# 11        cq  2017       12      1
# 12        cq  2018       01      2
# 13        cq  2018       02      2
# 14        cq  2018       03      2
# 15        cq  2018       04      2
# 16        cq  2018       05      2
# 17        cq  2018       06      2
# 18        cq  2018       07      2
# 19        cq  2018       08      2
# 20        cq  2018       09      2
# 21        cq  2018       10      2
# 22        cq  2018       11      2
# 23        cq  2018       12      2
# 24        cq  2019       01      3
# 25        cq  2019       02      3
# 26        cq  2019       03      3
# 0         dc  2015       01      1
# 1         dc  2016       01      2
# 2         dc  2017       01      3
# ..       ...   ...      ...    ...
# 6         ca  2007       01      6
# 7         ca  2007       02      6
# 8         ca  2008       01      7
# 9         ca  2008       02      7
# 10        ca  2009       01      8
# 11        ca  2009       02      8
# 12        ca  2010       01      9
# 13        ca  2010       02      9
# 14        ca  2011       01     10
# 15        ca  2011       02     10
# 16        ca  2012       01     11
# 17        ca  2012       02     11
# 18        ca  2013       01     12
# 19        ca  2013       02     12
# 20        ca  2014       01     13
# 21        ca  2014       02     13
# 22        ca  2015       01     14
# 23        ca  2015       02     14
# 24        ca  2016       01     15
# 25        ca  2016       02     15
# 26        ca  2017       01     16
# 27        ca  2017       02     16
# 28        ca  2018       01     17
# 29        ca  2018       02     17
# 30        ca  2019       01     18
# 31        ca  5555       01   None
# 0         lc  2018       01      1
# 1         lc  2018       02      1
# 2         lc  2019       01      2
# 3         lc  5555       01   None
#
# [1454 rows x 4 columns]

# %%
journals_groupbyID = journals_df.groupby('journalId')

# %%
journals_groupbyID.get_group('cq')
# Out:
#    journalId  year issueNum volume
# 0         cq  2017       01      1
# 1         cq  2017       02      1
# 2         cq  2017       03      1
# 3         cq  2017       04      1
# 4         cq  2017       05      1
# 5         cq  2017       06      1
# 6         cq  2017       07      1
# 7         cq  2017       08      1
# 8         cq  2017       09      1
# 9         cq  2017       10      1
# 10        cq  2017       11      1
# 11        cq  2017       12      1
# 12        cq  2018       01      2
# 13        cq  2018       02      2
# 14        cq  2018       03      2
# 15        cq  2018       04      2
# 16        cq  2018       05      2
# 17        cq  2018       06      2
# 18        cq  2018       07      2
# 19        cq  2018       08      2
# 20        cq  2018       09      2
# 21        cq  2018       10      2
# 22        cq  2018       11      2
# 23        cq  2018       12      2
# 24        cq  2019       01      3
# 25        cq  2019       02      3
# 26        cq  2019       03      3

# %% [markdown]
# ##### articles과 param (idPrefix, year, issueNum)을 통해 article 크롤링

# %% [raw]
# query {
#   articles(idPrefix: "cc", year: "2018", issueNum: "02") {
#     idPrefix
#     id
#     year
#     pubDate
#     keywords
#     title
#     abstract
#     authors {
#       affiliation
#       fullName
#       givenName
#       surname
#     }
#     #catalog
#     #contentType
#     #pages
#     #pubType
#     #sectionTitle
#     #volume
#   }
# }

# %%
def log_progress(sequence, every=None, size=None, name='Items'):
    from ipywidgets import IntProgress, HTML, VBox
    from IPython.display import display

    is_iterator = False
    if size is None:
        try:
            size = len(sequence)
        except TypeError:
            is_iterator = True
    if size is not None:
        if every is None:
            if size <= 200:
                every = 1
            else:
                every = int(size / 200)     # every 0.5%
    else:
        assert every is not None, 'sequence is iterator, set every'

    if is_iterator:
        progress = IntProgress(min=0, max=1, value=1)
        progress.bar_style = 'info'
    else:
        progress = IntProgress(min=0, max=size, value=0)
    label = HTML()
    box = VBox(children=[label, progress])
    display(box)

    index = 0
    try:
        for index, record in enumerate(sequence, 1):
            if index == 1 or index % every == 0:
                if is_iterator:
                    label.value = '{name}: {index} / ?'.format(
                        name=name,
                        index=index
                    )
                else:
                    progress.value = index
                    label.value = u'{name}: {index} / {size}'.format(
                        name=name,
                        index=index,
                        size=size
                    )
            yield record
    except:
        progress.bar_style = 'danger'
        raise
    else:
        progress.bar_style = 'success'
        progress.value = index
        label.value = "{name}: {index}".format(
            name=name,
            index=str(index or '?')
        )

# %%
all_articles_df = pd.DataFrame()

for key in log_progress(journals_groupbyID.groups.keys()):
    temp_df = journals_groupbyID.get_group(key)
    
    for _, row in temp_df.iterrows():
        resp = requests.post("https://csdl-api.computer.org/api/v1/graphql", 
                          json={
                              "variables":{"idPrefix":row['journalId'], "year":row['year'], "issueNum":row['issueNum']}, 
                              "query":'query ($idPrefix : String!, $year : String!, $issueNum : String!) { articles(idPrefix: $idPrefix, year: $year, issueNum: $issueNum) { idPrefix id year pubDate keywords title abstract authors { affiliation fullName givenName surname } } }'
                          })
        body = resp.json()
        labels = ['idPrefix', 'id', 'pubDate', 'keywords', 'title', 'abstract']
        all_articles_df = all_articles_df.append(pd.DataFrame.from_records(body['data']['articles'], columns=labels))
# Out:
# VBox(children=(HTML(value=''), IntProgress(value=0, max=26)))

# %%
all_articles_df
# Out:
#    idPrefix           id     pubDate  \
# 0        bd  13rRUwwslvh  2015-01-01
# 1        bd  13rRUygT7c8  2015-01-01
# 2        bd  13rRUwvT9j1  2015-01-01
# 3        bd  13rRUxBJhxj  2015-01-01
# 0        bd  13rRUxAStUe  2015-07-01
# 1        bd  13rRUxASu2L  2015-07-01
# 0        bd  13rRUxAASMi  1900-01-01
# 1        bd  13rRUwbJCYJ  1900-01-01
# 2        bd  13rRUzphDs2  1900-01-01
# 3        bd  13rRUNvyan1  1900-01-01
# 0        bd  13rRUNvya2X  1900-01-01
# 1        bd  13rRUwdIOYM  1900-01-01
# 2        bd  13rRUwvT9le  1900-01-01
# 3        bd  13rRUEgarDh  1900-01-01
# 4        bd  13rRUwvT9lf  1900-01-01
# 5        bd  13rRUzpQPNp  1900-01-01
# 0        bd  13rRUwInvLu  2016-01-01
# 1        bd  13rRUx0Pquv  2016-01-01
# 2        bd  13rRUx0xPuW  2016-01-01
# 3        bd  13rRUxjQyx8  2016-01-01
# 4        bd  13rRUzpQPNq  2016-01-01
# 5        bd  13rRUxASujo  2016-01-01
# 6        bd  13rRUy0qnIp  2016-01-01
# 7        bd  13rRUwh80Jo  2016-01-01
# 8        bd  13rRUILtJBR  2016-01-01
# 0        bd  13rRUNvgzbQ  2016-04-01
# 1        bd  13rRUwhpBSa  2016-04-01
# 2        bd  13rRUNvgzbP  2016-04-01
# 3        bd  13rRUy0qnIq  2016-04-01
# 4        bd  13rRUy2YLMW  2016-04-01
# ..      ...          ...         ...
# 2        ts  13rRUxC0SQa  1988-10-01
# 3        ts  13rRUwwJWHo  1988-10-01
# 4        ts  13rRUwbs2cr  1988-10-01
# 5        ts  13rRUx0xPjL  1988-10-01
# 6        ts  13rRUwgQps9  1988-10-01
# 7        ts  13rRUx0xPKi  1988-10-01
# 8        ts  13rRUxjQywO  1988-10-01
# 9        ts  13rRUxjyX5D  1988-10-01
# 10       ts  13rRUxly8YZ  1988-10-01
# 11       ts  13rRUxNW1Vi  1988-10-01
# 12       ts  13rRUNvPLbi  1988-10-01
# 13       ts  13rRUxEhFue  1988-10-01
# 14       ts  13rRUy2YLUs  1988-10-01
# 0        ts  13rRUygBw8C  1988-11-01
# 1        ts  13rRUx0gewB  1988-11-01
# 2        ts  13rRUyfKIJF  1988-11-01
# 3        ts  13rRUxNEqRD  1988-11-01
# 4        ts  13rRUxCitKZ  1988-11-01
# 5        ts  13rRUxBa5tm  1988-11-01
# 6        ts  13rRUwhHcSo  1988-11-01
# 7        ts  13rRUyfbwsi  1988-11-01
# 8        ts  13rRUygBw8D  1988-11-01
# 9        ts  13rRUIJuxrh  1988-11-01
# 10       ts  13rRUyYjK4d  1988-11-01
# 11       ts  13rRUwI5TYY  1988-11-01
# 12       ts  13rRUxly8UC  1988-11-01
# 13       ts  13rRUB6Sq25  1988-11-01
# 14       ts  13rRUxAAT2J  1988-11-01
# 15       ts  13rRUwjXZLl  1988-11-01
# 16       ts  13rRUytF42Y  1988-11-01
#
#                                              keywords  \
# 0                                                  []
# 1                                                  []
# 2   [Data Integration, Big Data, Data Mining, Feat...
# 3   [Semantics, Internet, Electronic Publishing, S...
# 0   [Data Models, Computational Modeling, Big Data...
# 1   [Distributed Databases, Base Stations, Data Pr...
# 0                                                  []
# 1   [Binary Codes, Error Correction Codes, Error C...
# 2   [Visualization, Search Engines, Google, Big Da...
# 3   [Training, Semantics, Machine Learning, Visual...
# 0                                                  []
# 1   [Merging, Indexing, Twitter, Big Data, Compute...
# 2   [Resource Description Framework, Indexes, Load...
# 3                                                  []
# 4   [Visualization, Semantics, Feature Extraction,...
# 5   [Binary Codes, Semantics, Robustness, Indexing...
# 0                                                  []
# 1   [Machine Learning Algorithms, Search Engines, ...
# 2   [Distortion Measurement, Big Data, Indexes, Co...
# 3                                                  []
# 4   [Videos, Feature Extraction, Machine Learning,...
# 5   [Media, Space Exploration, Big Data, Global Po...
# 6   [Sorting, Graphics Processing Units, Data Tran...
# 7   [Social Network Services, Cost Function, Perso...
# 8   [Data Visualization, Smart Cards, Media, Publi...
# 0                                                  []
# 1   [Collaboration, Context, Computational Modelin...
# 2   [Big Data, Navigation, Libraries, Couplings, S...
# 3   [Software Engineering, Big Data, Measurement, ...
# 4   [Cloud Computing, Big Data, Data Privacy, Encr...
# ..                                                ...
# 2   [Program Testing Static Concurrency Analysis S...
# 3   [Program Testing Data Flow Testing Pascal Adeq...
# 4   [Software Development Life Cycle Models Softwa...
# 5   [Transaction Processing Communicating Sequenti...
# 6   [Fault Tolerant Distributed Programs Industria...
# 7   [Specification Languages Prototyping Language ...
# 8   [Partial Match Range Queries Gray Codes Multia...
# 9   [Systems Analysis Synthesis Principles Respons...
# 10  [Reliable Message Service Distributed Processi...
# 11  [Software Costs Black Box Influence Function S...
# 12  [Software Reliability Markov Process Probabili...
# 13  [Data Structures Datatype Set Quicksort Multip...
# 14                                                 []
# 0   [Performance Evaluation Queueing Networks Load...
# 1   [Parallel Programming Concurrent C Ada Concurr...
# 2   [Automatic Programming Programming Environment...
# 3   [Formal Specification Submodule Specifications...
# 4   [Response Stability Scheduling Distributed Com...
# 5   [Program Testing Software Product Testing Auto...
# 6   [Programming Environments Program Construction...
# 7   [Information Systems Specification Techniques ...
# 8   [Web Structures Category Theory Software Tools...
# 9   [Storage Management Program Restructuring Mult...
# 10  [Software Reliability Software Complexity Metr...
# 11  [Distributed Databases Pipelined Processing Co...
# 12  [Parallel Architectures Relational Databases P...
# 13  [Storage Management DAG CAD Databases Direct A...
# 14  [Database Theory Multidimensional Partitioning...
# 15  [Software Reusability Software Tools GENESIS E...
# 16  [Subset Closures Relational Database Scheme El...
#
#                                                 title  \
# 0        Welcome to the IEEE Transactions on Big Data
# 1   Introduction to the IEEE Transactions on Big Data
# 2   Methodologies for Cross-Domain Data Fusion: An...
# 3   Embracing Information Explosion without Chokin...
# 0   Petuum: A New Platform for Distributed Machine...
# 1   SMC: A Practical Schema for Privacy-Preserved ...
# 0   Guest Editorial: Big Media Data: Understanding...
# 1   Code Consistent Hashing Based on Information-T...
# 2   Exploration of Image Search Results Quality As...
# 3   Weakly Semi-Supervised Deep Learning for Multi...
# 0     Guest Editorial: Big Data Analytics and the Web
# 1   LS-AMS: An Adaptive Indexing Structure for Rea...
# 2          Scale-Out Processing of Large RDF Datasets
# 3   Guest Editorial: Big Media Data: Understanding...
# 4   Learning Visual Semantic Relationships for Eff...
# 5   Robust Discrete Spectral Hashing for Large-Sca...
# 0   Guest Editorial: Big Scholar Data Discovery an...
# 1   AlgorithmSeer: A System for Extracting and Sea...
# 2                 Can Scientific Impact Be Predicted?
# 3   Guest Editorial: Big Media Data: Understanding...
# 4   Partial Copy Detection in Videos: A Benchmark ...
# 5   Personalized Travel Sequence Recommendation on...
# 6   GPU-Accelerated Large-Scale Distributed Sortin...
# 7            USTF: A Unified System of Team Formation
# 8   Visual Exploration of Changes in Passenger Flo...
# 0   Guest Editorial: Special Issue on Big Scholar ...
# 1   Scientific Article Recommendation: Exploiting ...
# 2   A Recommendation System Based on Hierarchical ...
# 3   How Long Will This Live? Discovering the Lifes...
# 4        Deduplication on Encrypted Big Data in Cloud
# ..                                                ...
# 2   Combining Static Concurrency Analysis with Sym...
# 3   An Applicable Family of Data Flow Testing Crit...
# 4   A Strategy for Comparing Alternative Software ...
# 5   A Distributed Deadlock Detection and Resolutio...
# 6   A Class of Inherently Fault Tolerant Distribut...
# 7       A Prototyping Language for Real-Time Software
# 8      Gray Codes for Partial Match and Range Queries
# 9   Applying Synthesis Principles to Create Respon...
# 10  PHILAN: A LAN Providing a Reliable Message Ser...
# 11       Understanding and Controlling Software Costs
# 12  Reliability of Systems with Markov Transfer of...
# 13                                Quicksort Revisited
# 14                        Guest Editor's Introduction
# 0   Approximate Analysis of Load Dependent General...
# 1   Rendezvous Facilities: Concurrent C and the Ad...
# 2   Description for a Tool Specifying and Prototyp...
# 3   Constructing Submodule Specifications and Netw...
# 4   Effects of Response and Stability on Schedulin...
# 5             An Approach to Software Product Testing
# 6   Software Prototyping by Relational Techniques:...
# 7   Modeling and Analysis of the Behavior of Infor...
# 8   Web Structures: A Tool for Representing and Ma...
# 9   Compile-Time Program Restructuring in Multipro...
# 10  Software Complexity and its Impact on Software...
# 11  Petri-Net-Based Modeling and Evaluation of Pip...
# 12  The Join Algorithms on a Shared-Memory Multipr...
# 13                 Clustering a DAG for CAD Databases
# 14  Algorithms for Multidimensional Partitioning o...
# 15  GENESIS: An Extensible Database Management System
# 16  An improved Algorithm Based on Subset Closures...
#
#                                              abstract
# 0   Presents an editorial introducting the inaugur...
# 1   Presents an introduction to the inaugural issu...
# 2   Traditional data mining usually deals with dat...
# 3   The explosive popularity of microblogging serv...
# 0   What is a systematic way to efficiently apply ...
# 1   Data collection is required to be safe and eff...
# 0                                                None
# 1   Learning based hashing techniques have attract...
# 2   Image retrieval plays an increasingly importan...
# 3   In this paper, we study leveraging both weakly...
# 0                                                None
# 1   Indexing microblogs for realtime search is cha...
# 2   Distributed RDF data management systems become...
# 3                                                None
# 4   In this paper, we investigate how to establish...
# 5   In big data era, the ever-increasing image dat...
# 0                                                None
# 1   Algorithms are usually published in scholarly ...
# 2   A widely used measure of scientific impact is ...
# 3                                                None
# 4   The goal of partial video copy detection is to...
# 5   Big data increasingly benefit both research an...
# 6   Splitter-based parallel sorting algorithms are...
# 7   Given a complex task requiring a specific set ...
# 8   Transportation systems in mega-cities are ofte...
# 0                                                None
# 1   Scientific article recommender systems are pla...
# 2   The scholarly literature is expanding at a rat...
# 3   We all want to be associated with long lasting...
# 4   Cloud computing offers a new way of service pr...
# ..                                                ...
# 2   Static concurrency analysis detects anomalous ...
# 3   The authors extend the definitions of the prev...
# 4   It is difficult to compare and contrast models...
# 5   The key idea of the algorithm is to let one tr...
# 6   Software for industrial process-control system...
# 7   PSDL is a language for describing prototypes o...
# 8   It is suggested that Gray codes be used to imp...
# 9   The general principles for formulating softwar...
# 10  A local area network (LAN) design based on a r...
# 11  A discussion is presented of the two primary w...
# 12  A software/hardware system is considered that ...
# 13  H.D. Mills and R.C. Linger (1986) propose addi...
# 14
# 0   A method for obtaining approximate solutions t...
# 1   The concurrent programming facilities in both ...
# 2   A specification language is introduced, able t...
# 3   Applications of an automated tool for module s...
# 4   An examination is made of the effects of respo...
# 5   An approach is presented that uses the followi...
# 6   A method for designing and prototyping program...
# 7   Many widely used specification techniques for ...
# 8   The authors introduce web structures and their...
# 9   An evaluation is made of a way to reduce the c...
# 10  To produce reliable software, its complexity m...
# 11  A description is given of a Petri-net-based me...
# 12  The authors develop and present a large set of...
# 13  A DAG (direct acyclic graph) is an important d...
# 14  The problem of multidimensional file partition...
# 15  A novel yet simple technology is presented tha...
# 16  An algorithm for synthesizing a better relatio...
#
# [22260 rows x 6 columns]

# %%
all_articles_df.to_pickle('all_articles_df.p')

# %%
all_articles_df = pd.read_pickle('all_articles_df.p')
